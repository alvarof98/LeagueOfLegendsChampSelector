# %%
from riotwatcher import LolWatcher, ApiError
import riotwatcher
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from time import sleep
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
from scipy.special import softmax
import os
import shutil

# %%
api_key = 'RGAPI-df101462-9dcb-46e1-81a4-8da803b27924'
watcher = LolWatcher(api_key)
my_region = 'euw1'

# %%
summoners = watcher.match.by_id(my_region, watcher.match.matchlist_by_puuid(my_region, watcher.summoner.by_name(my_region,'alvarof98')['puuid'])[0])['metadata']['participants']
summoners = [watcher.summoner.by_puuid(my_region, i)['name'] for i in summoners]
summoners
# Out:
# ['Ebers',
#  'alvarof98',
#  'xn88x',
#  'Rachell94',
#  'FRvsALL',
#  'WhereEaglesDare',
#  'TFS Senfei',
#  'lordletters',
#  'VBLODUS0secse',
#  'Gamers2 Caps']

# %%
watcher.summoner.by_name(my_region, 'alvarof98')
# Out:
# {'id': 'P_4EjJGQdqY4-RwuDXli2f0YeI2fRiVLfSrbFWGfdHHd5t0',
#  'accountId': 'MGX6g7z2rTZ8kvZ1OCD_clpRC6GFCYMnxaOJfpTUxA50DKQ',
#  'puuid': '-6QqogKKl14ju1MZplivTIaNe9QgEkoR0kaEAfMHlAjPDKMNfUIpv5ihibq0Fx4P5MdYQIaqTLcvQg',
#  'name': 'alvarof98',
#  'profileIconId': 1115,
#  'revisionDate': 1658350556000,
#  'summonerLevel': 214}

# %%
textos = []
summoners = ['thedatawarlock']
for i in summoners:
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"}
    reponse = requests.get(f'https://www.leagueofgraphs.com/summoner/euw/{i}', headers = headers)
    text = ''
    soup = BeautifulSoup(reponse.text, 'html.parser')
    for j in soup.find(attrs = {'class':'box tags-box'}).find_all('div'):
        if 'brown' in j['class']:
            continue
        elif 'lover' in j.text:
            text+='lover '
        else:
            text += j.text.replace('\n','').strip(' ') + ' '
    textos.append(text)
    sleep(0.5)
textos
# Out:
# ['lover lover Bounces back Snowballs lover Too confident Loses when behind Bad Starts ']

# %%
# Configuramos el modelo de sentimientos de hugging face

if 'cardiffnlp' in os.listdir():
    shutil.rmtree('cardiffnlp')
MODEL = f"cardiffnlp/twitter-xlm-roberta-base-sentiment"

tokenizer = AutoTokenizer.from_pretrained(MODEL, use_fast = False)
config = AutoConfig.from_pretrained(MODEL)

# %%
cont = 0
for i in textos:
    model = AutoModelForSequenceClassification.from_pretrained(MODEL)
    model.save_pretrained(MODEL)
    encoded_input = tokenizer(i, return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    print(f'{summoners[cont]} Indice de toxicidad:')
    for j in range(scores.shape[0]):
        l = config.id2label[ranking[j]]
        s = scores[ranking[j]]
        print(f"{j+1}) {l} {np.round(float(s), 4)}")
    print('====================================')
    cont +=1
# Out:
# thedatawarlock Indice de toxicidad:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#      11 print(f'{summoners[cont]} Indice de toxicidad:')
#      12 for j in range(scores.shape[0]):
# ---> 13     l = config.id2label[ranking[j]]
#      14     s = scores[ranking[j]]
#      15     print(f"{j+1}) {l} {np.round(float(s), 4)}")
#
# KeyError: 0.069443814

# %%
# Out:
# ['top',
#  'mid',
#  'mid',
#  'mid',
#  'sup',
#  'jgl',
#  'mid',
#  'mid',
#  'adc',
#  'sup',
#  'mid',
#  'mid',
#  'sup',
#  'jgl',
#  'sup',
#  'sup',
#  'sup',
#  'adc',
#  'top',
#  'mid',
#  'top',
#  'mid',
#  'top',
#  'jgl',
#  'adc',
#  'top',
#  'jgl',
#  'jgl',
#  'jgl',
#  'adc',
#  'jgl',
#  'top',
#  'mid',
#  'mid',
#  'top',
#  'top',
#  'top',
#  'top',
#  'jgl',
#  'top',
#  'jgl',
#  'mid',
#  'top',
#  'top',
#  'jgl',
#  'sup',
#  'jgl',
#  'top',
#  'top',
#  'adc',
#  'adc',
#  'adc',
#  'adc',
#  'sup',
#  'jgl',
#  'mid',
#  'mid',
#  'top',
#  'jgl',
#  'top',
#  'jgl',
#  'jgl',
#  'top',
#  'adc',
#  'mid',
#  'jgl',
#  'sup',
#  'jgl',
#  'mid',
#  'adc',
#  'sup',
#  'sup',
#  'top',
#  'mid',
#  'sup',
#  'jgl',
#  'adc',
#  'jgl',
#  'top',
#  'sup',
#  'sup',
#  'top',
#  'sup',
#  'mid',
#  'jgl',
#  'jgl',
#  'jgl',
#  'top',
#  'mid',
#  'top',
#  'top',
#  'jgl',
#  'sup',
#  'mid',
#  'top',
#  'sup',
#  'jgl',
#  'jgl',
#  'sup',
#  'sup',
#  'top',
#  'jgl',
#  'top',
#  'top',
#  'mid',
#  'adc',
#  'jgl',
#  'sup',
#  'sup',
#  'top',
#  'jgl',
#  'top',
#  'jgl',
#  'top',
#  'top',
#  'adc',
#  'jgl',
#  'sup',
#  'sup',
#  'sup',
#  'mid',
#  'mid',
#  'top',
#  'mid',
#  'jgl',
#  'sup',
#  'top',
#  'sup',
#  'adc',
#  'jgl',
#  'top',
#  'mid',
#  'adc',
#  'jgl',
#  'top',
#  'adc',
#  'adc',
#  'mid',
#  'sup',
#  'mid',
#  'jgl',
#  'jgl',
#  'mid',
#  'mid',
#  'jgl',
#  'jgl',
#  'adc',
#  'sup',
#  'jgl',
#  'mid',
#  'mid',
#  'top',
#  'sup',
#  'jgl',
#  'mid',
#  'adc',
#  'adc',
#  'sup',
#  'mid',
#  'sup']

# %%
df_champs['rol'] = rol

# %%
fh = open('campeones.json','w')
fh.write(df_champs.to_json())
fh.close()

# %%
df_champs = pd.read_json('campeones.json')
df_champs
# Out:
#       id   nombre  winrate                                             imagen  \
# 0    266   Aatrox     50.1  https://cdn.mobalytics.gg/assets/lol/images/dd...
# 1    103     Ahri     50.0  https://cdn.mobalytics.gg/assets/lol/images/dd...
# 2     84    Akali     49.4  https://cdn.mobalytics.gg/assets/lol/images/dd...
# 3    166   Akshan     51.4  https://cdn.mobalytics.gg/assets/lol/images/dd...
# 4     12  Alistar     47.8  https://cdn.mobalytics.gg/assets/lol/images/dd...
# ..   ...      ...      ...                                                ...
# 155  221     Zeri     49.6  https://cdn.mobalytics.gg/assets/lol/images/dd...
# 156  115    Ziggs     49.9  https://cdn.mobalytics.gg/assets/lol/images/dd...
# 157   26   Zilean     51.9  https://cdn.mobalytics.gg/assets/lol/images/dd...
# 158  142      Zoe     49.0  https://cdn.mobalytics.gg/assets/lol/images/dd...
# 159  143     Zyra     50.3  https://cdn.mobalytics.gg/assets/lol/images/dd...
#
#         hp  hpperlevel     mp  mpperlevel  movespeed  armor  ...  \
# 0    650.0         104    0.0         0.0        345     38  ...
# 1    570.0          96  418.0        25.0        330     18  ...
# 2    570.0         119  200.0         0.0        345     23  ...
# 3    630.0         104  350.0        40.0        330     26  ...
# 4    670.0         120  350.0        40.0        330     44  ...
# ..     ...         ...    ...         ...        ...    ...  ...
# 155  600.0         109  250.0        45.0        325     20  ...
# 156  606.0         106  480.0        23.5        325     22  ...
# 157  574.0          96  452.0        50.0        335     24  ...
# 158  630.0         106  425.0        25.0        340     21  ...
# 159  574.0          93  418.0        25.0        340     29  ...
#
#      hpregenperlevel  mpregen  mpregenperlevel  crit  critperlevel  \
# 0               1.00    0.000             0.00     0             0
# 1               0.60    8.000             0.80     0             0
# 2               0.90   50.000             0.00     0             0
# 3               0.65    8.175             0.70     0             0
# 4               0.85    8.500             0.80     0             0
# ..               ...      ...              ...   ...           ...
# 155             0.70    6.000             0.80     0             0
# 156             0.60    8.000             0.80     0             0
# 157             0.50   11.340             0.80     0             0
# 158             0.60    8.000             0.65     0             0
# 159             0.50   13.000             0.40     0             0
#
#      attackdamage  attackdamageperlevel  attackspeedperlevel  attackspeed  rol
# 0            60.0                  5.00                2.500        0.651  top
# 1            53.0                  3.00                2.000        0.668  mid
# 2            62.0                  3.30                3.200        0.625  mid
# 3            52.0                  3.50                4.000        0.638  mid
# 4            62.0                  3.75                2.125        0.625  sup
# ..            ...                   ...                  ...          ...  ...
# 155          50.0                  1.50                2.000        0.658  adc
# 156          54.0                  3.10                2.000        0.656  adc
# 157          52.0                  3.00                2.130        0.625  sup
# 158          58.0                  3.30                2.500        0.625  mid
# 159          53.0                  3.20                2.110        0.625  sup
#
# [160 rows x 25 columns]
